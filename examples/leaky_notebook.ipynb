# %% [markdown]
# # Leaky notebook
#
# Markdown cells are skipped, so they do not consume a cell number.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

rng = np.random.default_rng(11)
prices = pd.DataFrame({"close": 100 + np.cumsum(rng.normal(size=250))})

# %% [markdown]
# Build the features.

# %%
# !pip install -q scikit-learn
prices["target"] = prices["close"].shift(-1)
prices["trend"] = prices["close"].rolling(10, center=True).mean()

# %%
from sklearn.model_selection import train_test_split

frame = prices.dropna()
train, test = train_test_split(frame, test_size=0.25)
